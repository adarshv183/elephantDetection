# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ROOT_DIR = '/content/gdrive/My Drive/Elephant_Detector/model_2'

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8m.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "custom_data.yaml"), epochs=100)  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !scp -r /content/runs '/content/gdrive/My Drive/Elephant_Detector/model_2'

# %% [markdown]
# # Inference

# %%
# !yolo task=detect mode=predict model=/content/gdrive/MyDrive/Elephant_Detector/model_2/runs/detect/train3/weights/best.pt conf=0.55 source=/content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/images
# Out:
# Ultralytics YOLOv8.0.83 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/10 /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/images/VPCRWN1OQJUS.jpg: 640x640 1 elephant - forward, 7.4ms
# image 2/10 /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/images/VQAGW131PK1G.jpg: 640x640 1 elephant - left, 8.2ms
# image 3/10 /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/images/VQI76R40PHVS.jpg: 640x640 (no detections), 7.4ms
# image 4/10 /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/images/VQY6HJM16PE6.jpg: 640x640 1 elephant - forward, 7.4ms
# image 5/10 /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/images/VRHYMDQJVSRQ.jpg: 640x640 (no detections), 7.4ms
# image 6/10 /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/images/VRRKNL4F7MG1.jpg: 640x640 1 elephant - forward, 7.4ms
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !cp -r /content/runs/detect/predict /content/gdrive/MyDrive/Elephant_Detector/model_2/test_result_1

# %%
# !yolo task=detect mode=predict model=/content/gdrive/MyDrive/Elephant_Detector/model_2/runs/detect/train3/weights/best.pt conf=0.77 source=/content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/videos
# Out:
# Ultralytics YOLOv8.0.83 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/3 (1/235) /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/videos/elephants-126215.mp4: 384x640 (no detections), 49.6ms
# video 1/3 (2/235) /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/videos/elephants-126215.mp4: 384x640 (no detections), 6.3ms
# video 1/3 (3/235) /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/videos/elephants-126215.mp4: 384x640 (no detections), 7.1ms
# video 1/3 (4/235) /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/videos/elephants-126215.mp4: 384x640 1 elephant - right, 6.8ms
# video 1/3 (5/235) /content/gdrive/MyDrive/Elephant_Detector/model_2/data/test/videos/elephants-126215.mp4: 384x640 1 elephant - right, 7.1ms
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !cp -r /content/runs/detect/predict2 /content/gdrive/MyDrive/Elephant_Detector/model_2/test_result_1/video_test
